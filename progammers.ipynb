# %%
def solution(array, commands):
    return list(map(lambda x:sorted(array[x[0]-1:x[1]])[x[2]-1], commands))

answer = solution([1, 5, 2, 6, 3, 7, 4], [[2, 5, 3], [4, 4, 1], [1, 7, 3]])

print(answer)

# %%
def solution(sizes):
    answer = 0
    w = []
    h = []
    for size in sizes:
        w.append(size[0])
        h.append(size[1])

    min_w = min(w)
    min_h = min(h)
    
    while True:
        try:
            if h[w.index(min_w)-1] < min_w:
                w.remove(min_w)
                min_w = min(w)
                continue
        except:
            break
    
    while True:
        try:
            if w[h.index(min_h)-1] < min_h:
                h.remove(min_h)
                min_h = min(h)
                continue
        except:
            break

    a = min_w * min_h

    return answer

answer = solution([[60, 50], [30, 70], [60, 30], [80, 40]])
print(answer)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 34
#      30     a = min_w * min_h
#      32     return answer
# ---> 34 answer = solution([[60, 50], [30, 70], [60, 30], [80, 40]])
#      35 print(answer)
#
# Cell In[4], line 12, in solution(sizes)
#       9 min_w = min(w)
#      10 min_h = min(h)
# ---> 12 while True:
#      13     try:
#      14         if h[w.index(min_w)-1] < min_w:
#
# KeyboardInterrupt:
